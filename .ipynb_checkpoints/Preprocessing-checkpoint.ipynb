# %% [markdown]
# # Preprocessing

# %%
# Imports
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import seaborn as sns

# %%
pre = True

# %%
if pre:
    link = "data/2021_Alumnos_pre_normalizadas.csv"
else:
    link = "data/2021_Alumnos_post_normalizadas.csv"
data = pd.read_csv(link)
data.head()
# Out:
#             Curso   Nivel   Codigo  Edad Genero        Decision  \
# 0  AUTOMATIZACION  SENIOR   108472    13  Chico              Yo
# 1  AUTOMATIZACION  SENIOR   612000    14  Chica  Yo, Mis padres
# 2  AUTOMATIZACION  SENIOR   812078    15  Chico      Mis amigos
# 3  AUTOMATIZACION  SENIOR   902236    14  Chica              Yo
# 4  AUTOMATIZACION  SENIOR  1107000    16  Chico      Mis padres
#
#                       Otros_campus Ingenieria_antes Valoracion_ingenierias  \
# 0                               No            No sé                  Buena
# 1                               No            No sé                  Buena
# 2                               No               Sí                  Buena
# 3  2017, 2018, 2019, 2020 (online)               Sí                  Buena
# 4                               No            No sé            Me da igual
#
#    Dedicacion  ... Interes_asignaturas Salida_profesional  \
# 0         NaN  ...                   3                  3
# 1         NaN  ...                   4                  4
# 2         NaN  ...                   5                  5
# 3         NaN  ...                   4                  4
# 4         NaN  ...                   3                  3
#
#   Actividades_instituto Dificultad_asignaturas  Trabajo  Respeto_cientificos  \
# 0                     4                      2        3                    3
# 1                     4                      1        3                    3
# 2                     4                      4        5                    5
# 3                     4                      3        3                    4
# 4                     3                      3        3                    3
#
#    Efecto_vidas  No_gustar  Examenes  Decisiones_personales
# 0             4          2         1                      4
# 1             5          1         1                      5
# 2             5          2         4                      5
# 3             4          1         3                      4
# 4             3          3         3                      3
#
# [5 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['Curso', 'Nivel', 'Codigo', 'Edad', 'Genero', 'Decision',
#        'Otros_campus', 'Ingenieria_antes', 'Valoracion_ingenierias',
#        'Dedicacion', 'Trabajo_padre', 'Trabajo_madre', 'Posicion_clase',
#        'Tipo_estudiante', 'Gustar', 'Estudiar', 'Entender', 'No_entender',
#        'Profesional', 'Actividades', 'Carrera', 'Facilidad', 'Disfrutar',
#        'No_trabajo', 'Mundo_mejor', 'Interes_asignaturas',
#        'Salida_profesional', 'Actividades_instituto', 'Dificultad_asignaturas',
#        'Trabajo', 'Respeto_cientificos', 'Efecto_vidas', 'No_gustar',
#        'Examenes', 'Decisiones_personales'],
#       dtype='object')

# %% [markdown]
# ## Calculate Dimensions

# %% [markdown]
# ### Fix Negative variables

# %%
data.No_gustar = 6 - data.No_gustar
data.Profesional = 6 - data.Profesional
data.No_trabajo = 6 - data.No_trabajo
data.No_entender = 6- data.No_entender
data.Dificultad_asignaturas = 6 - data.Dificultad_asignaturas
data.Examenes = 6 - data.Examenes

# %%
data["Gusto"] = data[["Gustar", "Actividades", "Disfrutar", "Interes_asignaturas", "Actividades_instituto", "No_gustar"]].mean(axis=1)
data["Interes_profesional"] = data[["Estudiar", "Profesional", "Carrera", "No_trabajo", "Salida_profesional", "Trabajo"]].mean(axis = 1)
data["Autoeficacia"] = data[["No_entender", "Facilidad", "Dificultad_asignaturas", "Examenes"]].mean(axis = 1)
data["Utilidad"] = data[["Entender", "Mundo_mejor", "Respeto_cientificos", "Efecto_vidas", "Decisiones_personales"]].mean(axis = 1)

# %%
data.describe()
# Out:
#              Codigo        Edad  Dedicacion      Gustar    Estudiar  \
# count  5.730000e+02  573.000000         0.0  573.000000  573.000000
# mean   4.903353e+07   13.354276         NaN    4.230366    3.998255
# std    5.593143e+08    2.185890         NaN    0.860549    1.041951
# min    0.000000e+00    8.000000         NaN    1.000000    1.000000
# 25%    8.028360e+05   12.000000         NaN    4.000000    3.000000
# 50%    1.701657e+06   14.000000         NaN    4.000000    4.000000
# 75%    2.409000e+06   15.000000         NaN    5.000000    5.000000
# max    8.012011e+09   17.000000         NaN    5.000000    5.000000
#
#          Entender  No_entender  Profesional  Actividades     Carrera  ...  \
# count  573.000000   573.000000   573.000000   573.000000  573.000000  ...
# mean     4.439791     4.352531     3.846422     3.415358    3.893543  ...
# std      0.739936     0.830777     1.154563     1.133675    1.108223  ...
# min      1.000000     1.000000     1.000000     1.000000    1.000000  ...
# 25%      4.000000     4.000000     3.000000     3.000000    3.000000  ...
# 50%      5.000000     5.000000     4.000000     4.000000    4.000000  ...
# 75%      5.000000     5.000000     5.000000     4.000000    5.000000  ...
# max      5.000000     5.000000     5.000000     5.000000    5.000000  ...
#
#           Trabajo  Respeto_cientificos  Efecto_vidas   No_gustar    Examenes  \
# count  573.000000           573.000000    573.000000  573.000000  573.000000
# mean     3.406632             3.900524      4.139616    4.422339    3.425829
# std      1.164942             0.854165      0.845422    0.942206    1.217657
# min      1.000000             1.000000      1.000000    1.000000    1.000000
# 25%      3.000000             3.000000      4.000000    4.000000    3.000000
# 50%      3.000000             4.000000      4.000000    5.000000    3.000000
# 75%      4.000000             5.000000      5.000000    5.000000    4.000000
# max      5.000000             5.000000      5.000000    5.000000    5.000000
#
#        Decisiones_personales       Gusto  Interes_profesional  Autoeficacia  \
# count             573.000000  573.000000           573.000000    573.000000
# mean                4.052356    4.071553             3.778069      3.704188
# std                 0.924066    0.792361             0.894791      0.739861
# min                 1.000000    1.000000             1.000000      1.000000
# 25%                 3.000000    3.666667             3.166667      3.250000
# 50%                 4.000000    4.166667             3.833333      3.750000
# 75%                 5.000000    4.666667             4.500000      4.250000
# max                 5.000000    5.000000             5.000000      5.000000
#
#          Utilidad
# count  573.000000
# mean     4.222339
# std      0.590534
# min      1.000000
# 25%      4.000000
# 50%      4.200000
# 75%      4.600000
# max      5.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# ## Reduce Dataset

# %%
if pre:
    data_red = data[['Codigo', 'Edad', 'Nivel', 'Genero', 'Gusto', 'Interes_profesional', 'Autoeficacia', 'Utilidad']]
else:
    data_red = data[['Codigo', 'Nivel', 'Genero', 'Gusto', 'Interes_profesional', 'Autoeficacia', 'Utilidad']]
data_red
# Out:
#       Codigo  Edad   Nivel Genero     Gusto  Interes_profesional  \
# 0     108472    13  SENIOR  Chico  3.833333             3.166667
# 1     612000    14  SENIOR  Chica  4.166667             3.500000
# 2     812078    15  SENIOR  Chico  4.166667             4.833333
# 3     902236    14  SENIOR  Chica  4.333333             3.666667
# 4    1107000    16  SENIOR  Chico  3.000000             3.000000
# ..       ...   ...     ...    ...       ...                  ...
# 568  2101024    15  SENIOR  Chica  4.833333             4.166667
# 569  2703000    13  SENIOR  Chico  4.000000             3.166667
# 570  2908377    13  SENIOR  Chico  3.333333             2.000000
# 571  2912000    12  SENIOR  Chico  4.666667             4.000000
# 572  3008623    15  SENIOR  Chica  4.333333             4.333333
#
#      Autoeficacia  Utilidad
# 0            4.25       3.8
# 1            4.75       4.6
# 2            3.00       4.8
# 3            3.50       4.0
# 4            3.00       3.0
# ..            ...       ...
# 568          4.25       4.2
# 569          3.75       3.8
# 570          2.50       4.0
# 571          3.75       4.4
# 572          3.00       4.8
#
# [573 rows x 8 columns]

# %%
if pre:
    data_red.to_csv("data/2021_Alumnos_pre_red.csv", index = False)
else:
    data_red.to_csv("data/2021_Alumnos_post_red.csv", index = False)
